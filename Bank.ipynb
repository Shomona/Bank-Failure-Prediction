# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest, f_classif

df = pd.read_excel('Bank failure data.xlsx')


#Question1 :
#Ans: Citibank (South Dakota)

df_2009 = df[df['Quarter'] ==  '2009Q4']
#largest bank based on 2009q4
print(df_2009.loc[df_2009['Size'].idxmax()])
# Out:
# Bank Name                         Citibank (South Dakota), N.A.
# Quarter                                                  2009Q4
# Tier One                                                  12.78
# Texas                                                      0.15
# Size                                                    99.7772
# Brokered Deposits                                         95.78
# Net Chargeoffs                                             5.66
# Constr and Land Dev Loans                                     0
# Change in Portfolio Mix                                   25.28
# NP CRE to Assets                                              0
# Volatile Liabilities to Assets                            18.37
# Securities                                               107.54
# Failed during 2010Q2                                         No
# Cert Number                                               23360
# Name: 2618, dtype: object

# %%
#Question2:
#Ans: There are two peaks in an upward treand followed by a steep fall in 2009Q4 as can be seen from the graph below

df_time = df.copy()
df_time.Quarter = pd.to_datetime(df_time.Quarter)
df_time.set_index('Quarter', inplace=True)
df_plot = df_time[['Net Chargeoffs']]
df_plot.groupby('Quarter').mean().plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
#Question3:
#Ans: As can be seen from the correlation matrix and heatmap below there is negative correlation of -0.15


df_corr = df.copy()

df_corr['Failed during 2010Q2'] = df_corr['Failed during 2010Q2'].map({'Yes': 1, 'No': 0})

# calculate the correlation matrix
corr = df_corr.corr()

# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)


corr.style.background_gradient()
corr.style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_6b492f8c_2a8e_11e9_846e_f01898019376row0_col0 {
#             background-color:  #023858;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row0_col1 {
#             background-color:  #fff7fb;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row0_col2 {
#             background-color:  #fff7fb;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row0_col3 {
#             background-color:  #fff7fb;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row0_col4 {
#             background-color:  #fff7fb;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row0_col5 {
#             background-color:  #fff7fb;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row0_col6 {
#             background-color:  #f1ebf4;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row0_col7 {
#             background-color:  #fff7fb;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row0_col8 {
#             background-color:  #fff7fb;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row0_col9 {
#             background-color:  #dddbec;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row0_col10 {
#             background-color:  #fff7fb;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row0_col11 {
#             background-color:  #f7f0f7;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row1_col0 {
#             background-color:  #f0eaf4;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row1_col1 {
#             background-color:  #023858;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row1_col2 {
#             background-color:  #acc0dd;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row1_col3 {
#             background-color:  #c1cae2;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row1_col4 {
#             background-color:  #69a5cc;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row1_col5 {
#             background-color:  #a8bedc;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row1_col6 {
#             background-color:  #f1ebf4;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row1_col7 {
#             background-color:  #75a9cf;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row1_col8 {
#             background-color:  #b3c3de;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row1_col9 {
#             background-color:  #faf3f9;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row1_col10 {
#             background-color:  #6da6cd;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row1_col11 {
#             background-color:  #f5eff6;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row2_col0 {
#             background-color:  #fff7fb;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row2_col1 {
#             background-color:  #c4cbe3;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row2_col2 {
#             background-color:  #023858;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row2_col3 {
#             background-color:  #86b0d3;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row2_col4 {
#             background-color:  #d9d8ea;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row2_col5 {
#             background-color:  #91b5d6;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row2_col6 {
#             background-color:  #fff7fb;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row2_col7 {
#             background-color:  #c8cde4;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row2_col8 {
#             background-color:  #9ebad9;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row2_col9 {
#             background-color:  #fdf5fa;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row2_col10 {
#             background-color:  #bfc9e1;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row2_col11 {
#             background-color:  #fef6fa;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row3_col0 {
#             background-color:  #efe9f3;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row3_col1 {
#             background-color:  #c0c9e2;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row3_col2 {
#             background-color:  #6da6cd;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row3_col3 {
#             background-color:  #023858;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row3_col4 {
#             background-color:  #ced0e6;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row3_col5 {
#             background-color:  #93b5d6;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row3_col6 {
#             background-color:  #e5e1ef;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row3_col7 {
#             background-color:  #b5c4df;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row3_col8 {
#             background-color:  #91b5d6;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row3_col9 {
#             background-color:  #f9f2f8;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row3_col10 {
#             background-color:  #8bb2d4;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row3_col11 {
#             background-color:  #d4d4e8;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row4_col0 {
#             background-color:  #e8e4f0;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row4_col1 {
#             background-color:  #5ea0ca;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row4_col2 {
#             background-color:  #b8c6e0;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row4_col3 {
#             background-color:  #c4cbe3;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row4_col4 {
#             background-color:  #023858;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row4_col5 {
#             background-color:  #bdc8e1;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row4_col6 {
#             background-color:  #e6e2ef;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row4_col7 {
#             background-color:  #afc1dd;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row4_col8 {
#             background-color:  #b8c6e0;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row4_col9 {
#             background-color:  #f0eaf4;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row4_col10 {
#             background-color:  #a8bedc;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row4_col11 {
#             background-color:  #f2ecf5;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row5_col0 {
#             background-color:  #f4eef6;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row5_col1 {
#             background-color:  #b0c2de;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row5_col2 {
#             background-color:  #80aed2;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row5_col3 {
#             background-color:  #9cb9d9;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row5_col4 {
#             background-color:  #d0d1e6;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row5_col5 {
#             background-color:  #023858;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row5_col6 {
#             background-color:  #e3e0ee;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row5_col7 {
#             background-color:  #c4cbe3;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row5_col8 {
#             background-color:  #91b5d6;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row5_col9 {
#             background-color:  #fcf4fa;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row5_col10 {
#             background-color:  #6da6cd;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row5_col11 {
#             background-color:  #c4cbe3;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row6_col0 {
#             background-color:  #d8d7e9;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row6_col1 {
#             background-color:  #ede7f2;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row6_col2 {
#             background-color:  #eae6f1;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row6_col3 {
#             background-color:  #e0dded;
#         }    #T_6b492f8c_2a8e_11e9_846e_f01898019376row6_col4 {

# %%
#Question4:
#Ans: Texas, Constr and Land Dev Loans  

df_model = df.copy()

df_model = df_model.fillna(df_model.mean())
df_model['Failed during 2010Q2'] = df_model['Failed during 2010Q2'].map({'Yes': 1, 'No': 0})

#Separate train and predict data
train = df_model[df_model['Quarter'] < '2010']
predict = df_model[df_model['Quarter'] >= '2010']

#Drop all string data
train_cleaned = train.drop(train.select_dtypes(['object']), axis=1)
predict_cleaned = predict.drop(predict.select_dtypes(['object']), axis=1)

#Get train and predict values 
x_train = train_cleaned.drop('Failed during 2010Q2', axis = 1).values
y_train = train_cleaned['Failed during 2010Q2'].values

x_test = predict_cleaned.drop('Failed during 2010Q2', axis = 1).values
y_test = predict_cleaned['Failed during 2010Q2'].values


kbest = SelectKBest(f_classif, k=2)
kbest.fit(x_train,y_train)
mask = kbest.get_support() 
new_features = [] 
feature = list(train_cleaned)


for bool, feature in zip(mask, feature):
    if bool:
        new_features.append(feature)

#Top two predictors        
new_features
# Out:
# ['Texas', 'Constr and Land Dev Loans']

# %%
#Question5:
#Ans: Based on the head of the sorted dataframe based on probability of bank failing, the banks which are most likely to fail are:
#1.Butler Bank (MHC)
#2.City Bank
#3.First National Bank Rosedale Miss
#4.Bank of Florida - Southwest
#5.CF Bancorp

#Running logistic regression to predict
logisticRegr = LogisticRegression()
logisticRegr.fit(x_train, y_train)
prediction = logisticRegr.predict_proba(x_test)
prediction = prediction[:,1].tolist()

#Creating a new column called Prediction in predict dataframe
predict = predict.assign(Prediction=prediction)
#Sorting values in descending order of probability of bank failing and printing the head
predict.sort_values(by=['Prediction'], ascending = False).head()
# Out:
# /Users/shomonamukherjee/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#                               Bank Name Quarter  Tier One    Texas       Size  \
# 2819                  Butler Bank (MHC)  2010Q1     -0.15  2388.81  34.752791
# 2489                          City Bank  2010Q1      0.67  1683.34  49.801825
# 1729  First National Bank Rosedale Miss  2010Q1     -7.14  1571.49  19.534728
# 3409        Bank of Florida - Southwest  2010Q1     -2.98  1358.18  45.169655
# 2969                         CF Bancorp  2010Q1     -6.43  1042.75  55.097040
#
#       Brokered Deposits  Net Chargeoffs  Constr and Land Dev Loans  \
# 2819               0.00            8.66                      20.95
# 2489              29.05            0.00                      34.30
# 1729              17.55           76.34                       0.00
# 3409              11.72           14.62                      14.55
# 2969              21.56            4.46                      10.20
#
#       Change in Portfolio Mix  NP CRE to Assets  \
# 2819                    11.12          0.000000
# 2489                     1.67          5.761712
# 1729                     4.47          0.279575
# 3409                     0.70          7.334910
# 2969                     1.12          0.841962
#
#       Volatile Liabilities to Assets  Securities  Failed during 2010Q2  \
# 2819                           35.25       92.39                     1
# 2489                           22.44      101.34                     1
# 1729                           56.56       99.38                     1
# 3409                           36.72      100.08                     1
# 2969                           29.86       97.91                     1
#
#       Cert Number  Prediction
# 2819        26619         1.0
# 2489        21521         1.0
# 1729        15814         1.0
# 3409        35106         1.0
# 2969        30005         1.0
